# %% [raw]
# ### FROM GRAY TO RGB PYTHON

# %%
import cv2
import numpy as np

# Create random color image
image = (np.random.standard_normal([200,200,3]) * 255).astype(np.uint8)

# Convert to grayscale (1 channel)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Merge channels to create color image (3 channels)
gray_three = cv2.merge([gray,gray,gray])

# Fill a contour on both the single channel and three channel image
contour = np.array([[10,10], [190, 10], [190, 80], [10, 80]])
cv2.fillPoly(gray, [contour], [36,255,12])
cv2.fillPoly(gray_three, [contour], [36,255,12])

cv2.imshow('image', image)
cv2.imshow('gray', gray)
cv2.imshow('gray_three', gray_three)
cv2.waitKey()

# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
raw_data = pd.read_csv ("https://raw.githubusercontent.com/Pitsillides91/Python-Tutorials/master/Seaborn%20Tutorial/Marketing%20Raw%20Data.csv")

# %%
raw_data.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0  09/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %% [markdown]
# ### LINE GRAPH

# %%
raw_data.shape
# Out:
# (182, 11)

# %%
#Investigate the revenue by date
ax = sns.lineplot(x= 'Week_ID', y = 'Revenue', data = raw_data)

# %%
#Investigate the revenue by date adding categories
ax = sns.lineplot(x= 'Week_ID', y = 'Revenue', data = raw_data, hue = 'Promo')

# %%
#Investigate the revenue by date adding categories By promo woth style
ax = sns.lineplot(x= 'Week_ID', y = 'Revenue', data = raw_data, hue = 'Promo', style = 'Promo')

# %%
#Investigate the revenue by date adding categories By promo woth style
ax = sns.lineplot(x= 'Week_ID', y = 'Revenue', data = raw_data, hue = 'Promo', style = 'Promo')

# %%
#Investigate the revenue by date adding categories By promo woth style
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x= 'Week_ID', y = 'Revenue', data = raw_data, hue = 'Promo', style = 'Promo')

# %%
#Investigate the revenue by date adding categories By promo woth style
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x= 'Week_ID', y = 'Revenue', data = raw_data, hue = 'Promo', style = 'Promo', ci=False)

# %%
#Investigate the revenue by date adding categories By promo woth style
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x= 'Week_ID', y = 'Revenue', data = raw_data, hue = 'Promo', style = 'Promo', ci=False, markers=True)

# %%
#Investigate the revenue by date adding categories By promo woth style
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x= 'Month_ID', y = 'Revenue', data = raw_data, hue = 'Promo', style = 'Promo', ci=False, markers=True)

# %%
#Investigate the revenue by date adding categories By promo woth style
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x= 'Month_ID', y = 'Revenue', data = `raw_data, hue = 'Day_Name', style = 'Promo', ci=False, markers=True)

# %%
#Investigate the revenue by date adding categories By promo woth style
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x= 'Year', y = 'Revenue', data = raw_data, hue = 'Day_Name', style = 'Promo', ci=False, markers=True)

# %% [markdown]
# ### BAR PLOT

# %%
# Create a dataframe with the sum values
raw_data[['Revenue', 'Month_ID']].groupby('Month_ID').agg({'Revenue':'sum'})
# Out:
#           Revenue
# Month_ID
# 11         247620
# 12         361702
# 13         297244
# 14         299149
# 15         327216
# 16         324195
# 17          68724

# %%
# Create a dataframe with the mean values
raw_data[['Revenue', 'Month_ID']].groupby('Month_ID').agg({'Revenue':'mean'})
# Out:
#                Revenue
# Month_ID
# 11        11255.454545
# 12        11667.806452
# 13         9588.516129
# 14        10683.892857
# 15        10555.354839
# 16        10806.500000
# 17         7636.000000

# %%
#Investigate the revenue by date adding categories By promo woth style
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})

ax = sns.barplot(x= 'Month_ID', y = 'Revenue', data = raw_data)

# %%
#Investigate the revenue by date adding categories By promo woth style with no Confidence Interval CI
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})

ax = sns.barplot(x= 'Month_ID', y = 'Revenue', data = raw_data, ci=None)

# %%
#Investigate the revenue by date adding categories By promo woth style with no Confidence Interval CI 
# Total revenue by month by promo
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})

ax = sns.barplot(x= 'Month_ID', y = 'Revenue', data = raw_data, ci=None, hue = 'Promo' )

# %%
#Investigate the revenue by date adding categories By promo woth style with no Confidence Interval CI 
# Total revenue by month by promo. FLIP THE BARCHART, ORIENT = Horizontal
# AVERAGE REVENUE BY DAY BY PROMO BY YEAR
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})

ax = sns.barplot(y= 'Year', x = 'Revenue', data = raw_data, ci=None, hue = 'Promo', orient = 'h' )

# %%
#Investigate the revenue by date adding categories By promo woth style with no Confidence Interval CI 
# Total revenue by month by promo. FLIP THE BARCHART, ORIENT = Horizontal
# AVERAGE REVENUE BY DAY BY PROMO BY YEAR
# CHANGE THE COLOR 
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})

ax = sns.barplot(y= 'Year', x = 'Revenue', data = raw_data, ci=None, hue = 'Promo', orient = 'h', color = 'red' )

# %%
#Investigate the revenue by date adding categories By promo woth style with no Confidence Interval CI 
# Total revenue by month by promo. FLIP THE BARCHART, ORIENT = Horizontal
# AVERAGE REVENUE BY DAY BY PROMO BY YEAR
# CHANGE THE COLOR in #XXXXXX
# Increase the size
sns.set(rc={'figure.figsize':(12,10)})

ax = sns.barplot(y= 'Year', x = 'Revenue', data = raw_data, ci=None, hue = 'Promo', orient = 'h', color = '#11E5AD' )

# %% [markdown]
# ### HISTOGRAMS

# %%
raw_data['Revenue'].values ## Using values trasform in numpy array
# Out:
# array([  465, 10386, 12475, 11712, 10000, 12996, 11929,  5359, 12016,
#         7441,  8000, 15188,  3926, 14012, 34278, 18650,  5574, 12425,
#        14760,  8091, 10647,  7290,  4587, 12154,  8400, 20607,  3525,
#        10075,  9612,  6908, 12740, 15288,  6654,  9097,  8802, 11679,
#        11952,  4873,  8516, 18161,  8800,  7655, 12038, 10245, 11817,
#        15991, 21031, 36283, 23014,  5100,  7793,  9180,  9125, 21428,
#         9062,  9952,  4714,  9418, 16325,  6254,  7215, 11249, 12129,
#         4581,  8702,  5937, 14568, 21245, 11699,  9602,  8633,  7287,
#         4403,  3021, 24417,  6837, 12445, 10925,   292,  4085, 11156,
#        10485,  4225,  4953, 10479, 12783, 18678, 13281, 14356,  9095,
#         7264,  5263, 20860, 13602,  5519,  8741,  2184,  5772,  9987,
#         5966,  4910, 24247,  3025,  2409,  5171,  5847,  9135, 13719,
#        20237, 26608, 12789,  7222, 13212,  4376,  8223, 16727, 15474,
# ...

# %%
x = raw_data['Revenue'].values 
sns.distplot(x, color='blue')

# %%
#Plot the mean
mean = raw_data['Revenue'].mean()
x = raw_data['Revenue'].values 
sns.distplot(x, color='blue')
plt.axvline(mean,0,1, color='red')

# %%
# Investing the distribution of Visitors, adding the mean
#Plot the mean
mean = raw_data['Visitors'].mean()
x = raw_data['Visitors'].values 
sns.distplot(x, color='red')
plt.axvline(mean,0,1, color='blue')

# %% [markdown]
# ###  BOX PLOT

# %%
x = raw_data ['Revenue'].values
sns.set(rc={'figure.figsize':(12,10)})
print(raw_data.Revenue.median())
### The center line signifies the median
### The box in the middle show the beginning of Q1 (25th percent) and the end of the Q3(75%)
### The whiskers (left - right) show the minimum quartile and the maximum quartile
### The dots on he right are "outliers"
sns.boxplot(x)
# Out:
# 9452.0

# %%
### Investigate the distribution of revenue by day
x = raw_data ['Revenue'].values
sns.set(rc={'figure.figsize':(12,10)})
print(raw_data.Revenue.median())
### The center line signifies the median
### The box in the middle show the beginning of Q1 (25th percent) and the end of the Q3(75%)
### The whiskers (left - right) show the minimum quartile and the maximum quartile
### The dots on he right are "outliers"
sns.boxplot(x = 'Day_Name', y = 'Revenue', data = raw_data)
# Out:
# 9452.0

# %%
### Investigate the distribution of revenue by day
x = raw_data ['Revenue'].values
sns.set(rc={'figure.figsize':(12,10)})
print(raw_data.Revenue.median())
### The center line signifies the median
### The box in the middle show the beginning of Q1 (25th percent) and the end of the Q3(75%)
### The whiskers (left - right) show the minimum quartile and the maximum quartile
### The dots on he right are "outliers"
sns.boxplot(y = 'Day_Name', x = 'Revenue', data = raw_data, color = 'blue')
# Out:
# 9452.0

# %%
### Investigate the distribution of revenue by day
x = raw_data ['Revenue'].values
sns.set(rc={'figure.figsize':(12,10)})
print(raw_data.Revenue.median())
### The center line signifies the median
### The box in the middle show the beginning of Q1 (25th percent) and the end of the Q3(75%)
### The whiskers (left - right) show the minimum quartile and the maximum quartile
### The dots on he right are "outliers"
sns.boxplot(x = 'Day_Name', y = 'Revenue', data = raw_data, color = 'green', hue = 'Promo')
# Out:
# 9452.0

# %%
# Investing the distribution of revenue by day - by color - by data point (swarmplot)
sns.boxplot(x = 'Day_Name', y = 'Revenue', data = raw_data, color = 'yellow')
sns.swarmplot(x = 'Day_Name', y = 'Revenue', data = raw_data, color = 'blue')

# %% [markdown]
# ### Scatter plot

# %%
# Investigate the Relationship between Marketing Spend and Revenue
sns.scatterplot(x = 'Marketing Spend', y = 'Revenue', data = raw_data, hue = 'Promo', style = 'Promo')

# %%
# Investigate the Relationship between Marketing Spend and Visitors
sns.scatterplot(x = 'Marketing Spend', y = 'Visitors', data = raw_data, hue = 'Promo', style = 'Promo', size = 'Revenue', sizes=(40,400))

# %%
# Investigate the Relationship between Marketing Spend and Visitors -changing color & hue - adding size - by day
sns.scatterplot(x = 'Marketing Spend', y = 'Visitors', data = raw_data, hue = 'Day_Name', size = 'Revenue', sizes=(40,400))

# %% [markdown]
# ### LM plot

# %%
# Investigate the Relationship between Marketing Spend and Revenue -changing color 
## The line is the regression line
sns.lmplot(x = 'Marketing Spend', y = 'Revenue', data = raw_data, height = 10 )

# %%
# Investigate the Relationship between Marketing Spend and Revenue - changing color  hue and style
## The line is the regression line
sns.lmplot(x = 'Marketing Spend', y = 'Revenue', data = raw_data, hue = 'Promo', height = 10, ci = None, markers=['o','x','+'])

# %%
# Investigate the Relationship between Marketing Spend and Revenue - changing color  hue and style
## The line is the regression line
## relationship between marketing spend and revenue divided by promotion
sns.lmplot(x = 'Marketing Spend', y = 'Revenue', data = raw_data, col = 'Promo', height = 5, ci = None, 
          line_kws={'color':'red'},
          scatter_kws={'color':'green'}
          )

# %%
# Investigate the Relationship between Marketing Spend and Revenue - changing color  hue and style
## The line is the regression line
## relationship between marketing spend and revenue divided by Day_Name
sns.lmplot(x = 'Marketing Spend', y = 'Revenue', data = raw_data, col = 'Day_Name', height = 5, ci = None, 
          line_kws={'color':'red'},
          scatter_kws={'color':'green'}
          )

# %%
# Investigate the Relationship between Marketing Spend and Revenue - changing color  hue and style
## The line is the regression line
## relationship between marketing spend and revenue divided by Day_Name
sns.lmplot(x = 'Marketing Spend', y = 'Revenue', data = raw_data, col = 'Day_Name', height = 5, ci = None, 
          line_kws={'color':'red'},
          scatter_kws={'color':'green'},
          col_wrap = 3
          )

# %% [markdown]
#  ### SUB Plot

# %%
# Set up the matplotlib figure
fig, axis = plt.subplots(2,2, figsize = (12,7))

a = raw_data['Revenue'].values
b = raw_data['Visitors'].values
c = raw_data['Marketing Spend'].values

# Plot 1
sns.distplot(a, color='blue', ax=axis[0,0])
# Plot 2
sns.distplot(b, color='blue', ax=axis[0,1])
# Plot 3
sns.distplot(c, color='blue', ax=axis[1,0])
# Plot 4
# Investing the distribution of revenue by day - by color - by data point (swarmplot)
sns.boxplot(y = 'Day_Name', x = 'Revenue', data = raw_data, color = 'yellow')
sns.swarmplot(y = 'Day_Name', x = 'Revenue', data = raw_data, color = 'blue')

# %% [markdown]
# ### Pairplots

# %%
# Plot every single column against every single color
g = sns.pairplot(raw_data, plot_kws={'color':'green'})

# %%
# Plot every single selected column against every single color
g = sns.pairplot(raw_data[['Revenue','Marketing Spend','Visitors']], plot_kws={'color':'green'}, height=7)

# %%
# Plot every single selected column against every single color with regression
g = sns.pairplot(raw_data[['Revenue','Marketing Spend','Visitors','Promo']], height=5, hue = 'Promo', kind='reg')

# %%
# Plot every single selected column against every single color
g = sns.pairplot(raw_data[['Revenue','Marketing Spend','Visitors','Promo']], height=5, hue = 'Promo')

# %% [markdown]
# ### JointPlots

# %%
# Plot every single selected column against every single color
ax = sns.jointplot('Revenue','Marketing Spend', data = raw_data, color='green', height=10, kind = 'reg')

# %% [markdown]
# ### Heat Map

# %%
pc = raw_data[['Revenue','Marketing Spend','Visitors']].corr()

# %%
hm = sns.heatmap(pc)

# %%
hm = sns.heatmap(pc,
                 annot = True)

# %%
hm = sns.heatmap(pc,
                 annot = True,
                 annot_kws = {'size':50})

# %%
col = ["Visitors PC", "Revenue PC", "Marketing Spend PC"]
hm = sns.heatmap(pc,
                 annot = True,
                 annot_kws = {'size':50},
                 xticklabels=col,
                 yticklabels=col,
                 cmap='Accent')
## Cmap color
